# %%
import sys
import spotipy
import spotipy.util as util
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.learning_curve import validation_curve
import statsmodels.api as sm
import statsmodels.formula.api as sm
from surprise import Reader, Dataset
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import boxcox
from scipy.special import boxcox1p
import statsmodels.api as sm
import math
from sklearn.metrics import accuracy_score, mean_squared_error, mean_squared_log_error
import sklearn
from sklearn.cluster import KMeans
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %%
def call_api(username, scope):
    token = util.prompt_for_user_token(username,scope,client_id='4849430a2b114eae9d8eaf2c1f14f612',client_secret='11b854b009344409861112df56d9cf44',redirect_uri='http://127.0.0.1:8050/dashboard') 
    return token

# %%
token = call_api('mrethana', 'user-top-read')
sp = spotipy.Spotify(auth=token)

# %%
def create_top_tracks_dict(period):
    list_tracks =[]
    for offset in range(0,500,49):
        x = sp.current_user_top_tracks(49,offset,period)
        temp = [track for track in x['items']]
        list_tracks.extend(temp)
#     import pdb; pdb.set_trace()
    top_track_dict = [{'album':item['album']['name'], 'album_id':item['album']['id'], 'album_release':item['album']['release_date'],'artist':item['artists'][0]['name'],'track_name':item['name'],'track_id':item['id']} for item in list_tracks]
    for item in list_tracks:
        for dic in top_track_dict:
            if item['id'] == dic['track_id']:
                if len(item['artists']) > 1:
                    dic['feature'] = item['artists'][1]['name']
                else:
                    dic['feature'] = 'No Feature'
    return top_track_dict
# lt = create_top_tracks_dict('long_term')

# %%
def all_features(dictionary):
    all_features = []
    for item in dictionary:
        all_features.extend(sp.audio_features(item['track_id']))
    return all_features


def add_features(all_features, dictionary):
    for dic in dictionary:
        for item in all_features:
            if dic['track_id'] == item['id']:
                dic['danceability'] = item['danceability']
                dic['energy'] = item['energy']
                dic['loudness'] = item['loudness']
                dic['key'] = item['key']
                dic['acousticness'] = item['acousticness']
                dic['valence'] = item['valence']
                dic['tempo'] = item['tempo']

# %%
def regression_evaluation(target, X_list):
    split = train_test_split(X_list, target,random_state=69)
    X_train, X_test, y_train, y_test = split[0], split[1], split[2],split[3]
    X = X_train
    target = y_train
     
    X2 = sm.add_constant(X)
    est = sm.OLS(target, X2)
    est2 = est.fit()
    
    y_predicted = est2.fittedvalues
    y_actual = target
    rmse = math.sqrt(mean_squared_error(y_actual, y_predicted))
    residuals = y_actual-y_predicted
    
    plt.scatter(y_predicted,residuals)
    print(est2.summary())
    plt.scatter(y_predicted,residuals)
    plt.show()
    sns.distplot(residuals)
    print('RMSE=' + str(rmse))

# %%
def regression(target, X_list):
    split = train_test_split(X_list, target,random_state=69)
    X_train, X_test, y_train, y_test = split[0], split[1], split[2],split[3]
    X = X_train
    target = y_train
     
    X2 = sm.add_constant(X)
    est = sm.OLS(target, X2)
    est2 = est.fit()
    return est2.rsquared

# %%
def poly_regression(x, y, degree_range, xlim_min, xlim_max, ylim_min, ylim_max, alpha = .75,s = 5,width = 2.5):
    plt.figure(figsize = (10,10))
    plt.ylim(ylim_min, ylim_max)
    plt.xlim(xlim_min,xlim_max)
    
    #split inputs into training and test sets
    split = train_test_split(x,y)
    X_train, X_test, y_train, y_test = split[0], split[1], split[2],split[3]
    x = X_train
    y = y_train
    plt.scatter(x, y, s = s, alpha = alpha)
    
        
    for degree in degree_range:
        poly_model = make_pipeline(PolynomialFeatures(degree),
                               LinearRegression())
        poly_model.fit(x[:, np.newaxis], y)
        xfit = np.linspace(xlim_min,xlim_max, 10000)
        yfit = poly_model.predict(xfit[:, np.newaxis])
        plt.plot(xfit, yfit, label = 'degree={}'.format(degree),linewidth=width)
    plt.legend(loc = 'best')

# %%
def artist_features(features_for_tracks, dictionary):
    for dic in dictionary:
        for item in features_for_tracks:
            if item == None:
                pass
            else:
                if dic['track_id'] == item['id']:
                    dic['danceability'] = item['danceability']
                    dic['energy'] = item['energy']
                    dic['loudness'] = item['loudness']
                    dic['key'] = item['key']
                    dic['acousticness'] = item['acousticness']
                    dic['valence'] = item['valence']
                    dic['tempo'] = item['tempo']

# %%
def artist_tracks_dict(artist_name):
    list_tracks =[]
    for offset in range(0,500,50):
        x = sp.search(artist_name, 50, offset, type = 'track')
        temp = [track for track in x['tracks']['items']]
        list_tracks.extend(temp)
    top_track_dict = [{'album':item['album']['name'], 'album_id':item['album']['id'], 'album_release':item['album']['release_date'],'artist':item['artists'][0]['name'],'track_name':item['name'],'track_id':item['id']} for item in list_tracks]
    for piece in list_tracks:
        for section in top_track_dict:
            if piece['id'] == section['track_id']:
                if len(piece['artists']) > 1:
                    section['feature'] = piece['artists'][1]['name']
                else:
                    section['feature'] = 'No Feature'
    example = top_track_dict
    feat = all_features(example)
    artist_features(feat,example)
    return top_track_dict

# %%
token = call_api('mrethana', 'user-top-read')
sp = spotipy.Spotify(auth=token)

# %%
artist = artist_tracks_dict('aretha franklin')
# Out:
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs

# %%
a_df = pd.DataFrame(artist)
a_df = a_df.query("artist == 'Aretha Franklin'")

# %%
a_df.to_csv('artist.csv')

# %%
ldf = pd.read_csv('artist.csv', index_col = 0)

# %%
df = pd.read_csv('mrethana.csv', index_col = 0)

# %%
def relevant_features(dataframe):
    all_features = ['energy', 'valence', 'tempo','danceability','acousticness','key']
    rs = []
    for feature in all_features:
        yt,max_lambda =boxcox(dataframe.percentile +.01)
        xt,max_lambda=boxcox(dataframe[feature] + .01)
        r = regression(yt,xt)
        rs.append((r,feature))
    return [tuple[1] for tuple in sorted(rs, reverse = True)[0:3]]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
features = relevant_features(df)

# %%
features
# Out:
# ['valence', 'energy', 'key']

# %%
ldf.key = ldf.key/11
df.key = df.key/11
cluster_df = df

# %%
X = cluster_df[['valence','energy','key']]
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)
cluster_df['cluster'] = y_kmeans
print(len(y_kmeans[(y_kmeans == 0)]))
print(len(y_kmeans[(y_kmeans == 1)]))
print(len(y_kmeans[(y_kmeans == 2)]))
print(len(y_kmeans[(y_kmeans == 3)]))
print(len(y_kmeans[(y_kmeans == 4)]))
print(kmeans.cluster_centers_)
centers = kmeans.cluster_centers_
# Out:
# 102
# 93
# 48
# 51
# 0
# [[0.37592353 0.54214706 0.52941176]
#  [0.5687957  0.67649462 0.83479961]
#  [0.6913125  0.66510417 0.11363636]
#  [0.29932941 0.54201961 0.07308378]]

# %%
list(centers)[0]
# Out:
# array([0.37592353, 0.54214706, 0.52941176])

# %%
x_cent = [i[0] for i in centers]
y_cent = [i[1] for i in centers]
z_cent = [i[2] for i in centers]

# %%
from plotly import __version__
import plotly.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot,iplot
print (__version__) # requires version >= 1.9.0

#Always run this the command before at the start of notebook
init_notebook_mode(connected=True)
import plotly.graph_objs as go

trace1 = go.Scatter3d(
    z=cluster_df.valence,
    x=cluster_df.energy,
    y=cluster_df.key,
    mode='markers',
    marker=dict(
        size=8,
        color=y_kmeans,                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.8
    ))


trace2 = go.Scatter3d(
    x=centers[:, 0],
    y=centers[:, 1],
    z=centers[:, 2],
    mode='markers',
    marker=dict(
        size=8,
        color='black',                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.3
    )
)

data = [trace1,trace2]
layout = go.Layout(
                    scene = dict(
                    xaxis = dict(
                        title='Valence'),
                    yaxis = dict(
                        title='Energy'),
                    zaxis = dict(
                        title='Key'),),
                    width=700,
                    margin=dict(
                    r=20, b=10,
                    l=10, t=10)
                  )
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# 3.0.0
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mrethana/28.embed" height="525px" width="700px"></iframe>

# %%
profile = np.array([df[feat].mean() for feat in features])

# %%
profile2d = np.array([df[feat].mean() for feat in features[0:2]])

# %%
compare = ldf[[features[0],features[1],features[2]]].values
compare2d = ldf[[features[0],features[1]]].values

# %%
euc = df[[features[0],features[1],features[2]]].values

# %%
test = profile.reshape(1,-1)
test2 = compare[2].reshape(1,-1)

# %%
def cos_sim(a, b):
    dot_product = np.dot(a, b)
    norm_a = np.linalg.norm(a)
    norm_b = np.linalg.norm(b)
    return dot_product / (norm_a * norm_b)

# %%
def all_similarities(user,artist):
    cos_list = []
    for item in artist:
        x = cos_sim(user,item)
        cos_list.append(x)
    ldf['cos_similarity'] = cos_list

# %%
all_similarities(profile,compare)

# %%
profile
# Out:
# array([0.47513946, 0.60469728, 0.47897341])

# %%
ldf[(ldf.cos_similarity == ldf.cos_similarity.max())]
# Out:
#      acousticness                                              album  \
# 249        0.0101  Aretha Franklin Sings the Great Diva Classics:...
#
#                    album_id album_release           artist  danceability  \
# 249  0x4Mjq3IRy8lylTPh1uldm    2015-01-23  Aretha Franklin         0.701
#
#      energy         feature       key  loudness   tempo  \
# 249   0.956  Rafael Rosario  0.727273    -4.226  126.01
#
#                    track_id  \
# 249  12hrCYk7XS8ZZn6LCDb04O
#
#                                             track_name  valence  \
# 249  Rolling In the Deep (The Aretha Version) - Ros...    0.774
#
#      cos_similarity
# 249        0.999656

# %%
def euclidean_distance(user, artist):   
    return np.sqrt(np.sum((user - artist) ** 2))

# %%
ldf.nlargest(5,'cos_similarity')
# Out:
#      acousticness                                              album  \
# 249        0.0101  Aretha Franklin Sings the Great Diva Classics:...
# 84         0.1050  A Brand New Me: Aretha Franklin (with The Roya...
# 147        0.1960  Jewels In The Crown: All Star Duets With The Q...
# 315        0.6630                              This Christmas Aretha
# 22         0.7980                                         Soul Queen
#
#                    album_id album_release           artist  danceability  \
# 249  0x4Mjq3IRy8lylTPh1uldm    2015-01-23  Aretha Franklin         0.701
# 84   5ugc0oyFijTzQG3nHwRJ7A    2017-11-10  Aretha Franklin         0.272
# 147  3EeAD6RoOoCEBSj4ks8GqY    2007-11-09  Aretha Franklin         0.649
# 315  3JEvXjX2yApZaGLuXjBAc5    2008-10-14  Aretha Franklin         0.257
# 22   3nIxtIMxYqCiD7ZDE0payb    2007-10-29  Aretha Franklin         0.387
#
#      energy                       feature       key  loudness    tempo  \
# 249   0.956                Rafael Rosario  0.727273    -4.226  126.010
# 84    0.491  Royal Philharmonic Orchestra  0.363636    -8.808   77.785
# 147   0.623                      Fantasia  0.454545    -8.167  143.969
# 315   0.445                    No Feature  0.363636    -8.054   93.437
# 22    0.315                    No Feature  0.272727    -9.477  135.388
#
#                    track_id  \
# 249  12hrCYk7XS8ZZn6LCDb04O
# 84   2zXtZcDrVqbPNC6NgteIme
# 147  1pSuYDdmAC2Gd0ODVmIofm
# 315  4IoXVSluZ8MCAtelWqH6p7
# 22   3BucMqBqIR5Aw7MrUkF00y
#
#                                             track_name  valence  \
# 249  Rolling In the Deep (The Aretha Version) - Ros...    0.774
# 84   Let It Be (with The Royal Philharmonic Orchestra)    0.393
# 147                          Put You Up On Game - Main    0.508
# 315                       Hark! The Herald Angels Sing    0.311
# 22                                        Ain't No Way    0.232
#
#      cos_similarity
# 249        0.999656
# 84         0.999432
# 147        0.998980
# 315        0.998345
# 22         0.998322

# %%
def all_distance(user,artist):
    e_dist = []
    for item in artist:
        x = euclidean_distance(user,item)
        e_dist.append(x)
    return e_dist

# %%
ldf['e_1'] = all_distance(centers[0],compare)
ldf['e_2'] = all_distance(centers[1],compare)
ldf['e_3'] = all_distance(centers[2],compare)
ldf['e_4'] = all_distance(centers[3],compare)
ldf['euclidean'] = ldf[["e_1", "e_2",'e_3', 'e_4']].min(axis=1)

# %%
df['e_1'] = all_distance(centers[0],euc)
df['e_2'] = all_distance(centers[1],euc)
df['e_3'] = all_distance(centers[2],euc)
df['e_4'] = all_distance(centers[3],euc)
df['euclidean'] = df[["e_1", "e_2",'e_3', 'e_4']].min(axis=1)

# %%
df.head()
# Out:
#    acousticness             album                album_id album_release  \
# 0        0.4700          GO:OD AM  2Tyx5dLhHYkx6zeAdVaTzN    2015-09-18
# 1        0.0529   Dangerous Woman  3OZgEywV4krCZ814pTJWr7    2016-05-20
# 2        0.5690         Liberated  18fTRuJJDlbhrl2SREyuJA    2018-06-08
# 3        0.0155    A Moment Apart  3VzsvmhnUb9OZ59bq2aoNZ    2017-09-08
# 4        0.0626  Caracal (Deluxe)  08ipn1MH7xqgoqhUbtvCTy    2015-09-25
#
#           artist  danceability  energy       feature       key  loudness  \
# 0     Mac Miller         0.843   0.435        Miguel  0.727273    -8.442
# 1  Ariana Grande         0.662   0.602    No Feature  0.363636    -5.369
# 2       DeJ Loaf         0.739   0.605  Leon Bridges  0.909091    -3.632
# 3         ODESZA         0.566   0.587  Leon Bridges  0.545455    -5.960
# 4     Disclosure         0.704   0.628         Lorde  0.909091    -7.882
#
#      ...                                track_name valence rank  percentile  \
# 0    ...                    Weekend (feat. Miguel)   0.190    1          19
# 1    ...                           Dangerous Woman   0.290    2          19
# 2    ...                                 Liberated   0.623    3          19
# 3    ...      Across The Room (feat. Leon Bridges)   0.246    4          19
# 4    ...                                   Magnets   0.654    5          19
#
#    cluster       e_1       e_2       e_3       e_4  euclidean
# 0        0  0.291885  0.461918  0.825113  0.671840   0.291885
# 1        0  0.196078  0.552514  0.477005  0.296826   0.196078
# 2        1  0.457333  0.116485  0.800642  0.898686   0.116485
# 3        0  0.138381  0.442636  0.625196  0.477495   0.138381
# 4        1  0.478386  0.123007  0.797193  0.912191   0.123007
#
# [5 rows x 22 columns]

# %%
yt,max_lambda =boxcox(df.percentile +.01)
xt,max_lambda=boxcox(df.e_1 + .01)

# %%
regression_evaluation(yt, xt)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     3.831
# Date:                Thu, 16 Aug 2018   Prob (F-statistic):             0.0516
# Time:                        13:20:17   Log-Likelihood:                -535.61
# No. Observations:                 220   AIC:                             1075.
# Df Residuals:                     218   BIC:                             1082.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.2858      0.630      5.213      0.000       2.043       4.528
# x1            -1.8960      0.969     -1.957      0.052      -3.805       0.013
# ==============================================================================
# Omnibus:                       17.484   Durbin-Watson:                   2.216
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               13.046
# Skew:                          -0.488   Prob(JB):                      0.00147
# Kurtosis:                       2.314   Cond. No.                         7.23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RMSE=2.761211303675778
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %%
ldf[(ldf.euclidean == ldf.euclidean.min())]
# Out:
#      acousticness                album                album_id album_release  \
# 135         0.683  Let Me In Your Life  6Buhu2InRlKvtGC63NU2fC    1974-02-25
#
#               artist  danceability  energy     feature       key  loudness  \
# 135  Aretha Franklin         0.664   0.634  No Feature  0.181818    -6.348
#
#       tempo                track_id  \
# 135  93.914  3iX0BMs9dX9CsgrHhiB173
#
#                                             track_name  valence  \
# 135  Until You Come Back To Me [That's What I Am Go...    0.666
#
#      cos_similarity       e_1       e_2       e_3       e_4  euclidean
# 135        0.926634  0.461955  0.661543  0.079101  0.393358   0.079101

# %%
ldf = ldf.drop_duplicates('track_name')
rec = ldf.nsmallest(15,'euclidean')

# %%
rec
# Out:
#      acousticness                                              album  \
# 125        0.6580                                      Aretha (1980)
# 96         0.7820        The Very Best Of Aretha Franklin - The 70's
# 356        0.4550        The Very Best Of Aretha Franklin - The 70's
# 203        0.7550                                         Soul Queen
# 101        0.3340      Aretha Franklin Sings The Great Diva Classics
# 18         0.0473      Aretha Franklin Sings The Great Diva Classics
# 90         0.0646  A Brand New Me: Aretha Franklin (with The Roya...
# 418        0.4960  Rare & Unreleased Recordings From The Golden R...
# 65         0.0850  A Brand New Me: Aretha Franklin (with The Roya...
# 31         0.2570      Aretha Franklin Sings The Great Diva Classics
# 74         0.1750  A Brand New Me: Aretha Franklin (with The Roya...
# 432        0.8630  Rare & Unreleased Recordings From The Golden R...
# 72         0.5630  A Brand New Me: Aretha Franklin (with The Roya...
# 33         0.6240                                     Spanish Harlem
# 272        0.6240                         Respect - The Very Best of
#
#                    album_id album_release           artist  danceability  \
# 125  10K47n89LYsn4jZm9Zzald          1980  Aretha Franklin         0.329
# 96   2jfJMNfHt2kIqSOyQyq7Jn          1972  Aretha Franklin         0.647
# 356  2jfJMNfHt2kIqSOyQyq7Jn          1972  Aretha Franklin         0.520
# 203  3nIxtIMxYqCiD7ZDE0payb    2007-10-29  Aretha Franklin         0.270
# 101  6GDaEPN935WkElYXTR6Ejd    2014-10-17  Aretha Franklin         0.543
# 18   6GDaEPN935WkElYXTR6Ejd    2014-10-17  Aretha Franklin         0.654
# 90   5ugc0oyFijTzQG3nHwRJ7A    2017-11-10  Aretha Franklin         0.400
# 418  2oyxkNkpfi9anarmactB1a    2007-10-15  Aretha Franklin         0.530
# 65   5ugc0oyFijTzQG3nHwRJ7A    2017-11-10  Aretha Franklin         0.560
# 31   6GDaEPN935WkElYXTR6Ejd    2014-10-17  Aretha Franklin         0.551
# 74   5ugc0oyFijTzQG3nHwRJ7A    2017-11-10  Aretha Franklin         0.383
# 432  2oyxkNkpfi9anarmactB1a    2007-10-15  Aretha Franklin         0.502
# 72   5ugc0oyFijTzQG3nHwRJ7A    2017-11-10  Aretha Franklin         0.378
# 33   01XurvYS4xSvViTd1jXYXZ    1998-03-17  Aretha Franklin         0.680
# 272  3IadQMKTsvI9DhuE4UexFz    2017-03-25  Aretha Franklin         0.680
#
#      energy                       feature       key  loudness    tempo  \
# 125   0.582                    No Feature  0.545455    -5.548  107.186
# 96    0.617                    No Feature  0.181818    -8.901   95.004
# 356   0.454                    No Feature  0.090909   -10.616  110.480
# 203   0.577                    No Feature  0.000000    -8.195  170.250
# 101   0.568                    No Feature  0.000000    -6.486  104.173
# 18    0.679                    No Feature  0.727273    -5.460  107.961
# 90    0.535  Royal Philharmonic Orchestra  0.181818    -9.881   78.227
# 418   0.478                    No Feature  0.090909    -7.785  110.656
# 65    0.707  Royal Philharmonic Orchestra  0.000000    -7.553  109.189
# 31    0.512                    No Feature  0.454545    -6.889   95.024
# 74    0.459  Royal Philharmonic Orchestra  0.454545   -10.937   85.554
# 432   0.439                    No Feature  0.000000    -7.767  109.025
# 72    0.424  Royal Philharmonic Orchestra  0.000000    -9.142  140.635
# 33    0.540                    No Feature  0.181818    -9.831   94.548
# 272   0.540                    No Feature  0.181818    -9.831   94.548
#
#                    track_id  \
# 125  0xXH73mgW4Kc1dRZrHZHBE
# 96   1PbB82yaidq8X0XPhLlBek
# 356  2c3HrTyXKraoTdTlDBXpar
# 203  6hpATujo25ozqubXszUxwR
# 101  2sc45qVuZpUr44nCq06RDV
# 18   0UdRGHCSRvn85nN0IfHFmq
# 90   1XhePkOGNnquPQmGbq98s7
# 418  78onml5umFMhmgmcmmHzjw
# 65   5vW4aaWSi5xdPyRPLdfeQ3
# 31   5nSzvsTiu2hIYKGrDn141h
# 74   1VMRkA0JbEhUOhcThrjuNZ
# 432  19tWiFgvFFQwNRGJwd7dJl
# 72   0JZ2BxFK0aahCsyfFVKS3E
# 33   5mymaL5wREERekNoPojzyG
# 272  5uPU42LtgktLvxfYVs0678
#
#                                             track_name  valence  \
# 125                                    United Together    0.456
# 96   Until You Come Back To Me [That's What I Am Go...    0.654
# 356                                        I'm In Love    0.326
# 203                                              Angel    0.362
# 101                               Nothing Compares 2 U    0.376
# 18            Rolling In the Deep (The Aretha Version)    0.592
# 90   Son Of A Preacher Man (with The Royal Philharm...    0.279
# 418  I'm In Love - Alternate Vocal - Let Me In Your...    0.401
# 65   Don't Play That Song (You Lied) [with The Roya...    0.666
# 31                                             At Last    0.282
# 74       Angel (with The Royal Philharmonic Orchestra)    0.313
# 432  Can You Love Again - Hey Now Hey The Other Sid...    0.360
# 72   Border Song (Holy Moses) [with The Royal Philh...    0.335
# 33   Until You Come Back To Me (That's What I Am Go...    0.718
# 272  Until You Come Back to Me (That's What I Am Go...    0.718
#
#      cos_similarity       e_1       e_2       e_3       e_4  euclidean
# 125        0.996914  0.090873  0.324612  0.498744  0.499278   0.090873
# 96         0.927615  0.451388  0.661199  0.091406  0.378466   0.091406
# 356        0.921908  0.450052  0.813527  0.422534  0.093683   0.093683
# 203        0.844092  0.530740  0.865768  0.359336  0.102433   0.102433
# 101        0.846028  0.530043  0.863615  0.348948  0.109062   0.109062
# 18         0.991686  0.323368  0.110031  0.621776  0.729646   0.110031
# 90         0.951350  0.360925  0.728277  0.437696  0.110841   0.110841
# 418        0.915752  0.443879  0.787990  0.346130  0.121463   0.121463
# 65         0.845426  0.625778  0.840993  0.123730  0.408665   0.123730
# 31         0.985772  0.123836  0.503888  0.554253  0.383033   0.123836
# 74         0.990235  0.128366  0.507276  0.549380  0.390630   0.128366
# 432        0.848643  0.539601  0.892687  0.416898  0.140126   0.140126
# 72         0.848825  0.543976  0.902942  0.444975  0.143326   0.143326
# 33         0.908871  0.487691  0.683577  0.144955  0.432565   0.144955
# 272        0.908871  0.487691  0.683577  0.144955  0.432565   0.144955

# %%
trace1 = go.Scatter3d(
    x=x_cent,
    y=y_cent,
    z=z_cent,
    mode='markers',
    marker=dict(
        size=18,
        color='blue',                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.8
    )
)

trace2 = go.Scatter3d(
    x=ldf[features[0]],
    y=ldf[features[1]],
    z=ldf[features[2]],
    mode='markers',
    marker=dict(
        size=12,
        color='red',                # set color to an array/list of desired values
        colorscale='Earth',   # choose a colorscale
        opacity=0.4
    ),text= ldf['track_name']
)


data = [trace1,trace2]
layout = go.Layout(
                    scene = dict(
                    xaxis = dict(
                        title=features[0]),
                    yaxis = dict(
                        title=features[1]),
                    zaxis = dict(
                        title=features[2]),),
                    width=700,
                    margin=dict(
                    r=20, b=10,
                    l=10, t=10)
                  )
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='plot from API (17)')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mrethana/44.embed" height="525px" width="700px"></iframe>

# %%
id_add = list(rec['track_id'].to_dict().values())

# %%
token2 = call_api('mrethana', 'playlist-modify-public')
sp2 = spotipy.Spotify(auth=token2)

# %%
token = call_api('mrethana', 'user-top-read')
sp = spotipy.Spotify(auth=token)
# input('http://127.0.0.1:8050/dashboard?code=AQBnrGOn6GkHA0SYj7nadp-sCydBgpm5Y_laPI05mrkBLQD5xTtyaSX5jkoUk_4ZFLh4xB-0hBybST0w-yIYXYqewyamHzEST81hNgdNzWRL3JidvtbrTIkfQ9EddhaAKnt5-r3e0iLdbioa2PXgSwOotZ70ajQA8lu6H95XaJEBMEmQHeBn3i4WUEuZAITiX6j48bTcBp4BfqnHEzxYkhkbN6NBSVUl_y955_k')
# Out:
#             User authentication requires interaction with your
#             web browser. Once you enter your credentials and
#             give authorization, you will be redirected to
#             a url.  Paste that url you were directed to to
#             complete the authorization.
#
#
# Opened https://accounts.spotify.com/authorize?client_id=4849430a2b114eae9d8eaf2c1f14f612&response_type=code&redirect_uri=http%3A%2F%2F127.0.0.1%3A8050%2Fdashboard&scope=user-top-read in your browser
#
#
# Enter the URL you were redirected to: http://127.0.0.1:8050/dashboard?code=AQCHN65WJGKH3xeuQ4pRHkIzmy3Efs2X0Bd9wbcequufNubIY4YiNTjXbwxYQX7n9dbcQ61waFM2FF5pCzDEmZdKLkMGBaJhKtzNSpfLzOr5UX8AIDRWhCBUbKj0jrTR9kaZ9sFRkqgTUvY47AxbMISnjbE_VaCM14gWd9tWis-0bGp-WEx3F2Cq8d6qHnRdp5AOHcO53gPN-z_st33y5ZeoiY8

# %%
return_to_dict = rec['artist'].to_dict()
artist_name = list(return_to_dict.values())[0]
artist_name
# Out:
# 'Aretha Franklin'

# %%
sp2.user_playlist_create('mrethana',artist_name, True)
# Out:
# {'collaborative': False,
#  'description': None,
#  'external_urls': {'spotify': 'https://open.spotify.com/user/mrethana/playlist/4Dy1yITjkv7FwhAWZZ9g3Q'},
#  'followers': {'href': None, 'total': 0},
#  'href': 'https://api.spotify.com/v1/users/mrethana/playlists/4Dy1yITjkv7FwhAWZZ9g3Q',
#  'id': '4Dy1yITjkv7FwhAWZZ9g3Q',
#  'images': [],
#  'name': 'Aretha Franklin',
#  'owner': {'display_name': None,
#   'external_urls': {'spotify': 'https://open.spotify.com/user/mrethana'},
#   'href': 'https://api.spotify.com/v1/users/mrethana',
#   'id': 'mrethana',
#   'type': 'user',
#   'uri': 'spotify:user:mrethana'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'MSxlNDA1ZjYxMDAzZGUxNzUyMWE1ZGJlMWQwNjg2ZWViMWYzN2MzNWNh',
#  'tracks': {'href': 'https://api.spotify.com/v1/users/mrethana/playlists/4Dy1yITjkv7FwhAWZZ9g3Q/tracks',
#   'items': [],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0},
#  'type': 'playlist',
#  'uri': 'spotify:user:mrethana:playlist:4Dy1yITjkv7FwhAWZZ9g3Q'}

# %%
newest_id = sp2.user_playlists('mrethana')['items'][0]['id']

# %%
sp2.user_playlist_add_tracks('mrethana', newest_id, id_add, None)
# Out:
# {'snapshot_id': 'MixjOGJkZjVkMWQyNTE0MmM5ZWY4N2VjZjA5YzcxNDc5YWFhMGM4ZTk0'}

# %%
input('Enter - ')
if len(url) < 1: url = 'http://py4e-data.dr-chuck.net/known_by_Rhuairidh.html'
